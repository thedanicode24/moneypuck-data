# %% [markdown]
# # Skaters (Season 2024/25) - Penalty minutes

# %% [markdown]
# ## Step 0: Import libraries

# %%
import sys
import os
import pandas as pd

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from utils import df_utils, ftab_utils, pmf_utils, cdf_utils, modeling_distributions_utils, pdf_utils

# %% [markdown]
# ## Step 1: Import the dataset

# %%
#skaters_df = "https://moneypuck.com/moneypuck/playerData/seasonSummary/2024/regular/skaters.csv"
skaters_df = "../data/skaters.csv"
df = pd.read_csv(skaters_df)
df.head(5)
# Out:
#    playerId  season             name team position situation  games_played  \
# 0   8478047    2024  Michael Bunting  NSH        L     other            76
# 1   8478047    2024  Michael Bunting  NSH        L       all            76
# 2   8478047    2024  Michael Bunting  NSH        L      5on5            76
# 3   8478047    2024  Michael Bunting  NSH        L      4on5            76
# 4   8478047    2024  Michael Bunting  NSH        L      5on4            76
#
#    icetime  shifts  gameScore  ...  OffIce_F_xGoals  OffIce_A_xGoals  \
# 0   2237.0    37.0      26.19  ...             7.28            10.09
# 1  70819.0  1474.0      43.70  ...           161.54           187.75
# 2  59813.0  1294.0      43.70  ...           112.73           122.08
# 3      6.0     2.0       2.58  ...             0.20             0.17
# 4   8763.0   141.0      36.88  ...            23.81             2.60
#
#    OffIce_F_shotAttempts  OffIce_A_shotAttempts  xGoalsForAfterShifts  \
# ...

# %% [markdown]
# ## Step 2: Read the data

# %%
df_utils.print_df_size(df)
# Out:
# Number of samples: 4600
# Number of features: 154

# %%
df_utils.save_column_names(df)
# Out:
# Saved: names_columns.txt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Columns: 154 entries, playerId to fenwickAgainstAfterShifts
# dtypes: float64(147), int64(3), object(4)
# memory usage: 5.4+ MB

# %% [markdown]
# ## Step 3: Data cleaning

# %%
# Missing values?
df_utils.report_nan(df)
# Out:
# No missing values found.

# %%
df = df_utils.drop_duplicate_columns(df, ["faceoffsWon", "I_F_faceOffsWon"])
df = df_utils.drop_duplicate_columns(df, [ "penalityMinutes", "I_F_penalityMinutes"])
# Out:
# Dropped columns: ['I_F_faceOffsWon']
# Number of features: 153
# Dropped columns: ['I_F_penalityMinutes']
# Number of features: 152

# %% [markdown]
# ## Step 4: Variables and Filter

# %%
situation = "all"
feature = "penalityMinutes"
min_games_played = 20
name_player="Auston Matthews"

# %%
df_penalties = df[(df["situation"] == situation) & (df["games_played"] >= min_games_played)]

# %% [markdown]
# ## Step 5: Summary statistics and Frequency Tables

# %%
answer = df[df["situation"] == "all"].loc[lambda d: d[feature].idxmax()]
print(f"Player with most penality minutes: {answer["name"]} with {answer[feature]} minutes.")
# Out:
# Player with most penality minutes: Mathieu Olivier with 129.0 minutes.

# %%
ftab_utils.plot_ftab(df_penalties, feature, xlabel="Penality minutes")
# Out:
# Mean: 26.57
# Variance: 332.98
# Standard deviation: 18.23
# Mode: [14. 16.]

# %%
df1 = df_penalties[df_penalties["position"]!="D"]
df2 = df_penalties[df_penalties["position"]=="D"]

ftab_utils.plot_two_ftabs(df1, df2, feature, name1="Forward", name2="Defencemen", xlabel="Penalty minutes")
# Out:
# Cohen's effect size: -0.12

# %% [markdown]
# ## Step 6: Probability Mass Function

# %%
pmf_utils.plot_pmf(df_penalties, feature, xlabel="Penalty minutes", width=1)
# Out:
# Actual PMF:
# Mean: 26.57
# Variance: 332.51
# Standard deviation: 18.23
# Mode: 14.0
# Skewness: 1.45
#
# Observed PMF:
# Mean: 39.09
# Variance: 506.33
# Standard deviation: 22.50
# Mode: 16.0
# Skewness: 1.15

# %%
df1 = df_penalties[df_penalties["position"]!="D"]
df2 = df_penalties[df_penalties["position"]=="D"]

pmf_utils.plot_two_pmfs(df1, df2, feature, name1="Forward", name2="Defencemen", xlabel="Penalty minutes")

# %%
df1 = df_penalties[df_penalties["position"]!="D"]
df2 = df_penalties[df_penalties["position"]=="D"]

pmf_utils.plot_diff_pmfs(df1, df2, feature, name1="Forward", name2="Defencemen", xlabel="Penality minutes")

# %% [markdown]
# ## Step 7: Percentile Ranks and Cumulative Distribution Function
#
# Reference player: **Auston Matthews**.

# %%
vals = df_penalties[feature].values
ref = df_penalties[df_penalties["name"]==name_player][feature].values[0]

cdf_utils.percentile_rank(ref, vals, label=name_player)
cdf_utils.plot_cdf(ref, vals, label=name_player, xlabel="Penalty minutes")
# Out:
# Auston Matthews - Percentile rank: 47.42
# Median: 22.00
# Interquartile range: 22.00
# Quartile skewness: 0.27

# %%
vals1 = df_penalties[df_penalties["position"]!="D"][feature].values
vals2 = df_penalties[df_penalties["position"]=="D"][feature].values

cdf_utils.plot_two_cdfs(vals1, vals2, name1="Forward", name2="Defencemen", xlabel="Penalty minutes")

# %% [markdown]
# ## Step 8: Modeling Distributions

# %% [markdown]
# ## Step 9: Probability Density Function and Kernel Density Estimate
